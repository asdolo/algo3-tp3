# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
savingsTiemposA = pd.read_csv('1-savings/A/tiempo.csv')
savingsOptimosA = pd.read_csv('1-savings/A/optimo.csv')
savings = savingsTiemposA.merge(savingsOptimosA, on='n')

golosaTiemposA = pd.read_csv('2-golosa/A/tiempo.csv')
golosaOptimosA = pd.read_csv('2-golosa/A/optimo.csv')
golosa = golosaTiemposA.merge(golosaOptimosA, on='n')

sweepAlgorithmTiemposA = pd.read_csv('3-sweep-algorithm/A/tiempo.csv')
sweepAlgorithmOptimosA = pd.read_csv('3-sweep-algorithm/A/optimo.csv')
sweepAlgorithm = sweepAlgorithmTiemposA.merge(sweepAlgorithmOptimosA, on='n')

otraClusterizacionTiemposA = pd.read_csv('4-otra-clusterizacion/A/tiempo.csv')
otraClusterizacionOptimosA = pd.read_csv('4-otra-clusterizacion/A/optimo.csv')
otraClusterizacion = otraClusterizacionTiemposA.merge(otraClusterizacionOptimosA, on='n')

simulatedAnnealingTiemposA = pd.read_csv('5-simulated-annealing/A/tiempo.csv')
simulatedAnnealingOptimosA = pd.read_csv('5-simulated-annealing/A/optimo.csv')
simulatedAnnealing = simulatedAnnealingTiemposA.merge(simulatedAnnealingOptimosA, on='n')

# %% [markdown]
# # SAVINGS

# %%
#SAVINGS Complejidad savings (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

savings['SAV/N^3'] = savings['tiempo'] / savings['n']**3;
ax1 = sns.lineplot(x="n", y="SAV/N^3", data=savings.reset_index(), label="Saving", ax=ax);

#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

plt.ylim(-0.02,0.02);

plt.ylabel(r"F(G,N) = $\frac{tiempo(G,N)}{N^3}$", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None]

# %%
#SAVINGS Resultado vs optimo (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

ax1 = sns.lineplot(x="n", y="resultado", data=savings.reset_index(), label="Saving", ax=ax);
ax2 = sns.lineplot(x="n", y="optimo", data=savings.reset_index(), label="Optimo", ax=ax);

#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

#plt.ylim(-0.01,0.01);

plt.ylabel(r"Distancia recorrida", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None, None]

# %%
#SAVINGS Bar plot Diferencias entre Resultado vs optimo (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
savings['distanciaOptRes'] = savings['resultado'] / savings['optimo']
ax1 = sns.barplot(x="n", y="distanciaOptRes", data=savings,ax=ax)
#ax1 = sns.lineplot(x="n", y="resultado", data=savings.reset_index(), label="Saving", ax=ax);


#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

#plt.ylim(-0.01,0.01);

plt.ylabel(r"F(G,N) = $\frac{distancia(Saving)}{distancia(optimo)}$", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # GOLOSA

# %%
#GOLOSA Complejidad Golosa (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

golosa['GOL/N^3'] = golosa['tiempo'] / golosa['n']**3;
ax1 = sns.lineplot(x="n", y="GOL/N^3", data=golosa.reset_index(), label="Golosa", ax=ax);

#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

plt.ylim(-0.02,0.02);

plt.ylabel(r"F(G,N) = $\frac{tiempo(G,N)}{N^3}$", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None]

# %%
#GOLOSA Resultado vs optimo (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

ax1 = sns.lineplot(x="n", y="resultado", data=golosa.reset_index(), label="Golosa", ax=ax);
ax2 = sns.lineplot(x="n", y="optimo", data=golosa.reset_index(), label="Optimo", ax=ax);

#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

#plt.ylim(-0.01,0.01);

plt.ylabel(r"Distancia recorrida", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None, None]

# %%
#GOLOSA Bar plot Diferencias entre Resultado vs optimo (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
golosa['distanciaOptRes'] = golosa['resultado'] / golosa['optimo']
ax1 = sns.barplot(x="n", y="distanciaOptRes", data=golosa,ax=ax)
#ax1 = sns.lineplot(x="n", y="resultado", data=savings.reset_index(), label="Saving", ax=ax);


#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

#plt.ylim(-0.01,0.01);
plt.ylabel(r"F(G,N) = $\frac{distancia(Golosa)}{distancia(optimo)}$", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # SWEEP-ALGORITHM

# %%
#SWEEP-ALGORITHM Complejidad sweepAlgorithm (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

sweepAlgorithm['SWEEP/N^3'] = sweepAlgorithm['tiempo'] / sweepAlgorithm['n']**3;
ax1 = sns.lineplot(x="n", y="SWEEP/N^3", data=sweepAlgorithm.reset_index(), label="Sweep-algorithm", ax=ax);

#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

plt.ylim(-0.02,0.02);

plt.ylabel(r"F(G,N) = $\frac{tiempo(G,N)}{N^3}$", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None]

# %%
#SWEEP-ALGORITHM Resultado vs optimo (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

ax1 = sns.lineplot(x="n", y="resultado", data=sweepAlgorithm.reset_index(), label="Sweep-Algorithm", ax=ax);
ax2 = sns.lineplot(x="n", y="optimo", data=sweepAlgorithm.reset_index(), label="Optimo", ax=ax);

#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

#plt.ylim(-0.01,0.01);

plt.ylabel(r"Distancia recorrida", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None, None]

# %%
#SWEEP-ALGORITHM Bar plot Diferencias entre Resultado vs optimo (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sweepAlgorithm['distanciaOptRes'] = sweepAlgorithm['resultado'] / sweepAlgorithm['optimo']
ax1 = sns.barplot(x="n", y="distanciaOptRes", data=sweepAlgorithm,ax=ax)
#ax1 = sns.lineplot(x="n", y="resultado", data=savings.reset_index(), label="Saving", ax=ax);


#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

#plt.ylim(-0.01,0.01);
plt.ylabel(r"F(G,N) = $\frac{distancia(Sweep-Algorithm)}{distancia(optimo)}$", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # OTRA-CLUSTERIZACION

# %%
#OTRA-CLUSTERIZACION Complejidad otraClusterizacion (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

otraClusterizacion['OTRA/N^3'] = otraClusterizacion['tiempo'] / otraClusterizacion['n']**3;
ax1 = sns.lineplot(x="n", y="OTRA/N^3", data=otraClusterizacion.reset_index(), label="Otra-Clusterizacion", ax=ax);

#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

plt.ylim(-0.02,0.02);

plt.ylabel(r"F(G,N) = $\frac{tiempo(G,N)}{N^3}$", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None]

# %%
#OTRA-CLUSTERIZACION Resultado vs optimo (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

ax1 = sns.lineplot(x="n", y="resultado", data=otraClusterizacion.reset_index(), label="Otra-Clusterizacion", ax=ax);
ax2 = sns.lineplot(x="n", y="optimo", data=otraClusterizacion.reset_index(), label="Optimo", ax=ax);

#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

#plt.ylim(-0.01,0.01);

plt.ylabel(r"Distancia recorrida", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None, None]

# %%
#OTRA-CLUSTERIZACION Bar plot Diferencias entre Resultado vs optimo (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
otraClusterizacion['distanciaOptRes'] = otraClusterizacion['resultado'] / otraClusterizacion['optimo']
ax1 = sns.barplot(x="n", y="distanciaOptRes", data=otraClusterizacion,ax=ax)
#ax1 = sns.lineplot(x="n", y="resultado", data=savings.reset_index(), label="Saving", ax=ax);


#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

#plt.ylim(-0.01,0.01);
plt.ylabel(r"F(G,N) = $\frac{distancia(Otra-Clusterizacion)}{distancia(optimo)}$", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # SIMULATED-ANNEALING

# %%
#SIMULATED-ANNEALING Complejidad SIMULATED-ANNEALING (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
R=3
simulatedAnnealing['SIM/N^3'] = simulatedAnnealing['tiempo'] / (simulatedAnnealing['n']**3 * R);
ax1 = sns.lineplot(x="n", y="SIM/N^3", data=simulatedAnnealing.reset_index(), label="Simulated-Annealing", ax=ax);

#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

#plt.ylim(-0.02,0.02);

plt.ylabel(r"F(G,N) = $\frac{tiempo(G,N)}{N^3}$", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None]

# %%
#SIMULATED-ANNEALING Resultado vs optimo (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

ax1 = sns.lineplot(x="n", y="resultado", data=simulatedAnnealing.reset_index(), label="Simulated-Annealing", ax=ax);
ax2 = sns.lineplot(x="n", y="optimo", data=simulatedAnnealing.reset_index(), label="Optimo", ax=ax);

#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

#plt.ylim(-0.01,0.01);

plt.ylabel(r"Distancia recorrida", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None, None]

# %%
#SIMULATED-ANNEALING Bar plot Diferencias entre Resultado vs optimo (Uso instancias de clase A)
a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
simulatedAnnealing['distanciaOptRes'] = simulatedAnnealing['resultado'] / simulatedAnnealing['optimo']
ax1 = sns.barplot(x="n", y="distanciaOptRes", data=simulatedAnnealing,ax=ax)
#ax1 = sns.lineplot(x="n", y="resultado", data=savings.reset_index(), label="Saving", ax=ax);


#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

#plt.ylim(-0.01,0.01);
plt.ylabel(r"F(G,N) = $\frac{distancia(Simulated-Annealing)}{distancia(optimo)}$", fontsize=16);
plt.xlabel("N", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
#plt.savefig("FByBA_Complejidad.png")
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # EXPERIMENTOS

# %%
savingsTiemposCiudades = pd.read_csv('1-savings/CIUDADES/tiempo.csv')
savingsOptimosCiudades = pd.read_csv('1-savings/CIUDADES/optimo.csv')
savingsCiudades = savingsTiemposCiudades.merge(savingsOptimosCiudades, on='n')

golosaTiemposCiudades = pd.read_csv('2-golosa/CIUDADES/tiempo.csv')
golosaOptimosCiudades = pd.read_csv('2-golosa/CIUDADES/optimo.csv')
golosaCiudades = golosaTiemposCiudades.merge(golosaOptimosCiudades, on='n')

sweepAlgorithmTiemposCiudades = pd.read_csv('3-sweep-algorithm/CIUDADES/tiempo.csv')
sweepAlgorithmOptimosCiudades = pd.read_csv('3-sweep-algorithm/CIUDADES/optimo.csv')
sweepAlgorithmCiudades = sweepAlgorithmTiemposCiudades.merge(sweepAlgorithmOptimosCiudades, on='n')

otraClusterizacionTiemposCiudades = pd.read_csv('4-otra-clusterizacion/CIUDADES/tiempo.csv')
otraClusterizacionOptimosCiudades = pd.read_csv('4-otra-clusterizacion/CIUDADES/optimo.csv')
otraClusterizacionCiudades = otraClusterizacionTiemposCiudades.merge(otraClusterizacionOptimosCiudades, on='n')

simulatedAnnealingTiemposCiudades = pd.read_csv('5-simulated-annealing/CIUDADES/tiempo.csv')
simulatedAnnealingOptimosCiudades = pd.read_csv('5-simulated-annealing/CIUDADES/optimo.csv')
simulatedAnnealingCiudades = simulatedAnnealingTiemposCiudades.merge(simulatedAnnealingOptimosCiudades, on='n')

savingsTiemposCirculos = pd.read_csv('1-savings/CIRCULOS/tiempo.csv')
savingsOptimosCirculos = pd.read_csv('1-savings/CIRCULOS/optimo.csv')
savingsCirculos = savingsTiemposCirculos.merge(savingsOptimosCirculos, on='n')

golosaTiemposCirculos = pd.read_csv('2-golosa/CIRCULOS/tiempo.csv')
golosaOptimosCirculos = pd.read_csv('2-golosa/CIRCULOS/optimo.csv')
golosaCirculos = golosaTiemposCirculos.merge(golosaOptimosCirculos, on='n')

sweepAlgorithmTiemposCirculos = pd.read_csv('3-sweep-algorithm/CIRCULOS/tiempo.csv')
sweepAlgorithmOptimosCirculos = pd.read_csv('3-sweep-algorithm/CIRCULOS/optimo.csv')
sweepAlgorithmCirculos = sweepAlgorithmTiemposCirculos.merge(sweepAlgorithmOptimosCirculos, on='n')

otraClusterizacionTiemposCirculos = pd.read_csv('4-otra-clusterizacion/CIRCULOS/tiempo.csv')
otraClusterizacionOptimosCirculos = pd.read_csv('4-otra-clusterizacion/CIRCULOS/optimo.csv')
otraClusterizacionCirculos = otraClusterizacionTiemposCirculos.merge(otraClusterizacionOptimosCirculos, on='n')

otraClusterizacionTiemposCirculos = pd.read_csv('4-otra-clusterizacion/CIRCULOS/tiempo.csv')
otraClusterizacionOptimosCirculos = pd.read_csv('4-otra-clusterizacion/CIRCULOS/optimo.csv')
otraClusterizacionCirculos = otraClusterizacionTiemposCirculos.merge(otraClusterizacionOptimosCirculos, on='n')

#simulatedAnnealingTiemposCirculos = pd.read_csv('5-simulated-annealing/CIRCULOS/tiempo.csv')
#simulatedAnnealingOptimosCirculos = pd.read_csv('5-simulated-annealing/CIRCULOS/optimo.csv')
#simulatedAnnealingCirculos = simulatedAnnealingTiemposCirculos.merge(simulatedAnnealingOptimosCirculos, on='n')

# %% [markdown]
# # CIUDADES

# %%
#CIUDADES Bar plot Diferencias entre Resultados
df = pd.DataFrame(columns=['algoritmo', 'n', 'resultado','optimo'])
contador=0
df.loc[contador] = ['Heurística de savings',savingsCiudades['n'][0],savingsCiudades['resultado'][0],savingsCiudades['optimo'][0]]
contador=contador+1
df.loc[contador] = ['Heurística golosa',golosaCiudades['n'][0],golosaCiudades['resultado'][0],golosaCiudades['optimo'][0]]
contador=contador+1
df.loc[contador] = ['Cluster-first, route-second con sweep algorithm',sweepAlgorithmCiudades['n'][0],sweepAlgorithmCiudades['resultado'][0],sweepAlgorithmCiudades['optimo'][0]]
contador=contador+1
df.loc[contador] = ['Cluster-first, route-second con otra clusterización',otraClusterizacionCiudades['n'][0],otraClusterizacionCiudades['resultado'][0],otraClusterizacionCiudades['optimo'][0]]
contador=contador+1
df.loc[contador] = ['Simulated-Annealing',simulatedAnnealingCiudades['n'][0],simulatedAnnealingCiudades['resultado'][0],simulatedAnnealingCiudades['optimo'][0]]
contador=contador+1

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

ax1 = sns.barplot(x="algoritmo", y="resultado",hue="algoritmo", data=df,ax=ax)

plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
plt.axhline(y=df["optimo"][0], color='r', linestyle='-')
x_axis = ax1.axes.get_xaxis()
x_axis.set_visible(False)

# %%
#CIUDADES Bar plot Diferencias entre Resultados
df = pd.DataFrame(columns=['algoritmo', 'n', 'resultado','optimo'])
contador=0
df.loc[contador] = ['Heurística de savings',savingsCiudades['n'][1],savingsCiudades['resultado'][1],savingsCiudades['optimo'][1]]
contador=contador+1
df.loc[contador] = ['Heurística golosa',golosaCiudades['n'][1],golosaCiudades['resultado'][1],golosaCiudades['optimo'][1]]
contador=contador+1
df.loc[contador] = ['Cluster-first, route-second con sweep algorithm',sweepAlgorithmCiudades['n'][1],sweepAlgorithmCiudades['resultado'][1],sweepAlgorithmCiudades['optimo'][1]]
contador=contador+1
df.loc[contador] = ['Cluster-first, route-second con otra clusterización',otraClusterizacionCiudades['n'][1],otraClusterizacionCiudades['resultado'][1],otraClusterizacionCiudades['optimo'][1]]
contador=contador+1
df.loc[contador] = ['Simulated-Annealing',simulatedAnnealingCiudades['n'][1],simulatedAnnealingCiudades['resultado'][1],simulatedAnnealingCiudades['optimo'][1]]
contador=contador+1

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
ax1 = sns.barplot(x="algoritmo", y="resultado",hue="algoritmo", data=df,ax=ax)
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
plt.axhline(y=df["optimo"][0], color='r', linestyle='-')
x_axis = ax1.axes.get_xaxis()
x_axis.set_visible(False)

# %% [markdown]
# # CIRCULOS

# %%
#CIUDADES Bar plot Diferencias entre Resultados
df = pd.DataFrame(columns=['algoritmo', 'n', 'resultado','optimo'])
contador=0
df.loc[contador] = ['Heurística de savings',savingsCirculos['n'][0],savingsCirculos['resultado'][0],savingsCirculos['optimo'][0]]
contador=contador+1
df.loc[contador] = ['Heurística golosa',golosaCirculos['n'][0],golosaCirculos['resultado'][0],golosaCirculos['optimo'][0]]
contador=contador+1
df.loc[contador] = ['Cluster-first, route-second con sweep algorithm',sweepAlgorithmCirculos['n'][0],sweepAlgorithmCirculos['resultado'][0],sweepAlgorithmCirculos['optimo'][0]]
contador=contador+1
df.loc[contador] = ['Cluster-first, route-second con otra clusterización',otraClusterizacionCirculos['n'][0],otraClusterizacionCirculos['resultado'][0],otraClusterizacionCirculos['optimo'][0]]
contador=contador+1

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

ax1 = sns.barplot(x="algoritmo", y="resultado",hue="algoritmo", data=df,ax=ax)

plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
plt.axhline(y=df["optimo"][0], color='r', linestyle='-')
x_axis = ax1.axes.get_xaxis()
x_axis.set_visible(False)

# %%
#CIUDADES Bar plot Diferencias entre Resultados
df = pd.DataFrame(columns=['algoritmo', 'n', 'resultado','optimo'])
contador=0
df.loc[contador] = ['Heurística de savings',savingsCirculos['n'][1],savingsCirculos['resultado'][1],savingsCirculos['optimo'][1]]
contador=contador+1
df.loc[contador] = ['Heurística golosa',golosaCirculos['n'][1],golosaCirculos['resultado'][1],golosaCirculos['optimo'][1]]
contador=contador+1
df.loc[contador] = ['Cluster-first, route-second con sweep algorithm',sweepAlgorithmCirculos['n'][1],sweepAlgorithmCirculos['resultado'][1],sweepAlgorithmCirculos['optimo'][1]]
contador=contador+1
df.loc[contador] = ['Cluster-first, route-second con otra clusterización',otraClusterizacionCirculos['n'][1],otraClusterizacionCirculos['resultado'][1],otraClusterizacionCirculos['optimo'][1]]
contador=contador+1

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)

ax1 = sns.barplot(x="algoritmo", y="resultado",hue="algoritmo", data=df,ax=ax)

plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
plt.axhline(y=df["optimo"][0], color='r', linestyle='-')
x_axis = ax1.axes.get_xaxis()
x_axis.set_visible(False)
